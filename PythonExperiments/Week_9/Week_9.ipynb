# %% [markdown]
# # **Challenge-Based Exercises on Pivot Tables, Grouping, Filtering, and Statistical Operations**

# %%
# !pip install -U gdown

import gdown

# Step 1: Provide the Google Drive file ID
file_id = "1iddDlhB1PPEXq_5qXC0FtSp3OgbxYHmv"
url = f"https://drive.google.com/uc?id={file_id}"

# Step 2: Download and name the file appropriately (update the extension if it's Excel)
output = "employee_data.csv"
gdown.download(url, output, quiet=False)
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1iddDlhB1PPEXq_5qXC0FtSp3OgbxYHmv
# To: /content/employee_data.csv
# 100%|██████████| 8.44k/8.44k [00:00<00:00, 2.61MB/s]
# 'employee_data.csv'

# %%
import pandas as pd

# Read the file (change to pd.read_excel() if it's an Excel file)
df = pd.read_csv("employee_data.csv")  # or .xlsx if needed
df.head()
# Out:
#    EmployeeID Department  Gender  Age  JoiningYear  Salary  PerformanceScore  \
# 0        1001  Marketing  Female   44         2022  141884                 3
# 1        1002      Sales  Female   23         2017   59285                 1
# 2        1003         IT  Female   48         2019   72626                 3
# 3        1004      Sales    Male   23         2018   77808                 3
# 4        1005      Sales    Male   47         2011  123464                 5
#
#    WorkHoursPerWeek  RemoteWork  LeftCompany
# 0                48           0            0
# 1                36           0            1
# 2                49           1            0
# 3                35           0            1
# 4                30           0            1

# %%
# What is the average salary of employees grouped by department?

# Create a pivot table to show average PerformanceScore by Gender and Department.

# Find the department with the highest average WorkHoursPerWeek.

# How many employees joined each year? Show this as a time series.

# Calculate the median salary of employees who work remotely, grouped by department.

# Which department has the most employees who left the company?

# Compare average salaries between genders in the IT department.

# Create a MultiIndex groupby on Department and Gender to find mean WorkHoursPerWeek.

# Identify the correlation between Age, Salary, and WorkHoursPerWeek.

# Create a crosstab of RemoteWork and LeftCompany.

# Which gender has the highest average PerformanceScore across all departments?

# Rank employees based on their salary within their department.

# Which JoiningYear has the most employees still in the company?

# Find employees who are above 50 years old and still working.

# Compute average salary increase trend (assuming salary grows by 5% annually since joining).

# Create bins of Age and find average salary for each bin.

# Create a pivot table showing total number of employees by JoiningYear and Department.

# Identify if remote work is more common in a specific department.

# Find standard deviation of salaries for each department.

# Plot a histogram of PerformanceScore for male employees.

# How does WorkHoursPerWeek affect the chance of leaving the company?

# Find top 5 highest earning employees in each department.

# Calculate cumulative salary by department.

# Create a boolean mask to filter out underperformers (PerformanceScore <= 2).

# Which department has the highest gender diversity?

# Create a new column that calculates tenure based on 2025 as the current year.

# Find outliers in salary using the IQR method.

# Use .query() to find all employees in Marketing with Salary > 100000 and PerformanceScore > 4.

# For each department, find the employee with the max PerformanceScore.

# Create a pivot table to show % of employees who work remotely by department and gender.
